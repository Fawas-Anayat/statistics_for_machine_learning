# %% [markdown]
# ## Inferential Statistics

# %% [markdown]
# #### student study hours vs exam performance

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.random.seed(42)
record={
    'name':np.random.choice(['a','b','c','d','e','f','g','h'],size=8),
    'study_hours':[2,3,5,6,7,8,9,9],
    'exam_score':[35,40,56,71,77,82,88,92]
}
df=pd.DataFrame(record)
df.head()
# Out:
#   name  study_hours  exam_score
# 0    g            2          35
# 1    d            3          40
# 2    e            5          56
# 3    g            6          71
# 4    c            7          77

# %%
df.describe()
# Out:
#        study_hours  exam_score
# count     8.000000    8.000000
# mean      6.125000   67.625000
# std       2.642374   21.639498
# min       2.000000   35.000000
# 25%       4.500000   52.000000
# 50%       6.500000   74.000000
# 75%       8.250000   83.500000
# max       9.000000   92.000000

# %%
plt.figure(figsize=(10,5))
plt.title('study hours VS Exam Score')
plt.xlabel('study hours')
plt.ylabel('exam score')
plt.xticks([1,2,3,4,5,6,7,8])
plt.yticks([15,30,45,60,75,90])
# plt.scatter(df['study_hours'],df['exam_score'])
plt.plot(df['study_hours'],label='study hours')
plt.plot(df['exam_score'],label='exam score')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.title('Study hours VS exam score')
plt.xlabel('study hours')
plt.ylabel('exam score')
slope ,intercept=np.polyfit(df['study_hours'],df['exam_score'],1)
line=[slope*x+intercept for x in df['study_hours']]
plt.scatter(df['study_hours'],df['exam_score'],color='blue')
plt.plot(df['study_hours'],line,color='red',label='best fit line')
plt.legend()
plt.show()

# %%
df['name'].count()
# Out:
# 8

# %%
b=[0,3,6,10]
plt.figure(figsize=(8,4))
plt.hist(df['study_hours'],density=False,bins=b)
plt.xticks(b)
plt.xlabel('intervals for study hours')
plt.ylabel('count of students')
plt.grid()

# %% [markdown]
# ### Probability Density Function (PDF)

# %%
b=[0,3,6,10]
plt.figure(figsize=(8,4))
plt.hist(df['study_hours'],density=True,bins=b)
plt.xticks(b)
plt.xlabel('intervals for study hours')
plt.ylabel('PDF')
plt.grid()

# %% [markdown]
# ### Cumulative Distribution Function

# %%
b=[0,3,6,10]
plt.figure(figsize=(8,4))
plt.hist(df['study_hours'],density=True,bins=b,cumulative=True)
plt.xticks(b)
plt.xlabel('intervals for study hours')
plt.ylabel('CDF')
plt.grid()

# %%
plt.figure(figsize=(8,4))
sns.histplot(df['study_hours'], bins=10, kde=True)  # kde=True overlays smooth curve
plt.xlabel("Study Hours")
plt.ylabel("Frequency")
plt.title("Histogram with KDE")
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.hist(df['study_hours'], bins=10, density=True, alpha=0.6, color='skyblue')
sns.kdeplot(df['study_hours'], color="red")  # smooth line
plt.title("PDF of Study Hours")
plt.grid()
plt.show()

# %% [markdown]
# ### Cumulative Distribution Function

# %%
plt.figure(figsize=(8,4))
sns.ecdfplot(df['study_hours'])  # Empirical CDF
plt.title("CDF of Study Hours")
plt.show()

# %% [markdown]
# ### Q-Q plot
# The Q-Q plot shows that the points are approximately on the line therefore the data is nearly normal

# %%
import scipy.stats as stats

stats.probplot(df['study_hours'], dist="norm", plot=plt)
plt.title("Q-Q Plot")
plt.show()
